# %% [markdown]
# # Processing ERA5 data

# %% [markdown]
# ### Set up
# #### Packages

# %%
import numpy as np
import xarray as xr
import pandas as pd
from datetime import datetime
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
import datetime as dt
from datetime import timedelta
xr.set_options(display_expand_data=False);
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client
from dask.diagnostics import ProgressBar
from Processing_functions import AddCyclic, FixLongitude
import jinja2

# %% [markdown]
# #### Filepaths & name variables

# %%
## File name
#filename = 'adaptor.mars.internal-1724343246.1971328-17478-4-18f75df5-b6ea-4074-b3d0-ae2a89d93078.nc'
# filename = ['adaptor.mars.internal-1722442425.33003-18562-5-5c282c66-88bc-4aee-b110-b6ac3b0e6798.nc',
#             'adaptor.mars.internal-1722460351.557278-10990-5-7fb9f3c3-08d3-4022-8346-4639691c93ec.nc',
#             'adaptor.mars.internal-d6422ec0407b4656e511650f2a83def1_mod.nc']
filename = ['data_stream-moda_stepType-avgua.nc']
filename = ['628820391fd6fa0023dc859e9994ed92.nc']

## Filepaths
path_to_arch = "/glade/work/glydia/processed_ERA5_data/"
comp = 'atm'
var_ind = 5

# Variables
var_list = {'atm': [['t2m','TREFHT'],['msl','PSL'],['z','Z3'],['tciw','TGCLDIWP'],['tclw','TGCLDLWP'],['avg_tnswrf','FSNTOA']],
            'ice': [['siconc','aice']]}
var = var_list[comp][var_ind][0]
var2 = var_list[comp][var_ind][1]

# Extensions
h_ext = {'atm': ['.h0.'],
       'ice': ['.h.']}

path_to_outdata = '/glade/work/glydia/processed_ERA5_data/'

# %%
cluster = PBSCluster(cores    = 1,
                     memory   = '25GiB',
                     queue    = 'casper',
                     walltime = '02:00:00',
                     log_directory = '/glade/u/home/glydia/python/logs/',
                     account  = 'UCUB0137',
                     name='piControl_'+var)
cluster.scale(4*9)
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://128.117.208.97:33551' processes=0 threads=0, memory=0 B>

# %%
## Chunking variables
time_ch = 72
chunks = {
    'atm': {'time': time_ch, 'latitude': 23, 'longitude': 480},
    'ice': {'time': time_ch, 'latitude': 23, 'longitude': 480}
}

# %% [markdown]
# ### Load & modify data
# #### Control data

# %%
# %%time

yr_range = np.array([str(i) for i in np.arange(1950,2025)])
## Load data
# Open dataset
print(path_to_arch+filename[0])
#ds = dask.delayed(xr.open_dataset(path_to_arch+filename,chunks=chunks[comp]))
if var2 == 'RESTOM':
    ds = xr.open_mfdataset(path_to_arch+filename,chunks=chunks[comp])
    ds_sw = ds[var[0]]
    ds_lw = ds[var[1]]
    
else:
    if len(filename) > 1:
        paths = [path_to_arch+f for f in filename]
        ds_list = []
        for p in paths:
            print(p)
            da = xr.open_dataset(p)
            da = da.assign_coords(dict(longitude=(((da.longitude+180) % 360)-180)))
            da = da.sortby('longitude','ascending')
            print('fixed longitude upon opening')
            da = da[var]
            if comp == 'ice':
                da = da.loc[dict(latitude=slice(90,50))]
                print('slice lat')
            ds_list.append(da)
    
        dsv = xr.concat(ds_list,dim='time')
        dsv = dsv.sortby('time', 'ascending')
        print('concatenated')
    else:
        path = path_to_arch+filename[0]
        da = xr.open_dataset(path)
        da = da.assign_coords(dict(longitude=(((da.longitude+180) % 360)-180)))
        da = da.sortby('longitude','ascending')
        print('fixed longitude upon opening')
        da = da[var]
        da = da.rename({'valid_time':'time'})
        dsv = da.sortby('time','ascending')
    

    # dates = dsv.date.values
    # times = []
    # for d in dates:
    #     times.append(datetime.strptime(str(d), '%Y%m%d'))
    # times = np.array(times)
    # dsv = dsv.rename({'date':'time'})
    # dsv = dsv.assign_coords({'time': times})

#del ds

processed_list = []
for i in range(0,len(yr_range)):
    startyr = yr_range[i]
    endyr = yr_range[i]
    ann_slice = dsv.sel(time=slice(startyr+'-01-01',endyr+'-12-17')) 
    print('sliced '+startyr+'-01-01 to '+endyr+'-12-17')

    if var == 'z':
        ann_slice = ann_slice/9.81
    
        fixedcoord_data = ann_slice.rename({'longitude':'lon','latitude':'lat', 'pressure_level':'lev'})
    else:
        fixedcoord_data = ann_slice.rename({'longitude':'lon','latitude':'lat'})
    fixedname_data = fixedcoord_data.rename(var2)
    print('   fixed coordinate and variable names')

    latfix_data = fixedname_data.sortby('lat','ascending')

    # addcyc_data = dask.delayed(AddCyclic)(latfix_data)
    lonfix_data = FixLongitude(latfix_data, False)
    print('   added cyclic coordinate')
    # addcyc_data = AddCyclic(fixedname_data)

    # processed_list.append(addcyc_data)
    processed_list.append(lonfix_data)

# processed_comp = dask.compute(*processed_list)
print('computed list')

processed_out = xr.concat(processed_list,dim='time')
# processed_out = xr.concat(processed_comp,dim='time').chunk({'time':88})
print('concatenated data')

if var2 != 'Z3':
    processed_out.to_netcdf(path_to_outdata+'ERA5'+h_ext[comp][0]+var2+'.195001-202412.'+'nc', 
                                format='NETCDF4',encoding={var2: {"zlib": True, "complevel": 1}})
else:
    processed_out = processed_out.chunk()
        
    processed_out.sel(time=slice('1950-01-01','1950-12-31')).to_zarr(path_to_outdata+'ERA5'+h_ext[comp][0]+var2+'.195001-202412.'+'zarr', 
                            group=var2)
    print('saved initial zarr store')
    for i in range(1,len(yr_range)):
        yr = str(yr_range[i])
        print('   saving year '+yr)
        
        processed_out.sel(time=slice(yr+'-01-01',yr+'-12-31')).to_zarr(path_to_outdata+'ERA5'+h_ext[comp][0]+var2+'.195001-202412.'+'zarr', 
                            append_dim='time', mode='a-',group=var2)
    
print('wrote data to disk')
# Out:
# /glade/work/glydia/processed_ERA5_data/628820391fd6fa0023dc859e9994ed92.nc
# fixed longitude upon opening
# sliced 1950-01-01 to 1950-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1951-01-01 to 1951-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1952-01-01 to 1952-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1953-01-01 to 1953-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1954-01-01 to 1954-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1955-01-01 to 1955-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1956-01-01 to 1956-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1957-01-01 to 1957-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1958-01-01 to 1958-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1959-01-01 to 1959-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1960-01-01 to 1960-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1961-01-01 to 1961-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1962-01-01 to 1962-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1963-01-01 to 1963-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1964-01-01 to 1964-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1965-01-01 to 1965-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1966-01-01 to 1966-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1967-01-01 to 1967-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1968-01-01 to 1968-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1969-01-01 to 1969-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1970-01-01 to 1970-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1971-01-01 to 1971-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1972-01-01 to 1972-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1973-01-01 to 1973-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1974-01-01 to 1974-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1975-01-01 to 1975-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1976-01-01 to 1976-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1977-01-01 to 1977-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1978-01-01 to 1978-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1979-01-01 to 1979-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1980-01-01 to 1980-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1981-01-01 to 1981-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1982-01-01 to 1982-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1983-01-01 to 1983-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1984-01-01 to 1984-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1985-01-01 to 1985-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1986-01-01 to 1986-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1987-01-01 to 1987-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1988-01-01 to 1988-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1989-01-01 to 1989-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1990-01-01 to 1990-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1991-01-01 to 1991-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1992-01-01 to 1992-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1993-01-01 to 1993-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1994-01-01 to 1994-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1995-01-01 to 1995-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1996-01-01 to 1996-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1997-01-01 to 1997-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1998-01-01 to 1998-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 1999-01-01 to 1999-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2000-01-01 to 2000-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2001-01-01 to 2001-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2002-01-01 to 2002-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2003-01-01 to 2003-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2004-01-01 to 2004-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2005-01-01 to 2005-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2006-01-01 to 2006-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2007-01-01 to 2007-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2008-01-01 to 2008-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2009-01-01 to 2009-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2010-01-01 to 2010-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2011-01-01 to 2011-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2012-01-01 to 2012-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2013-01-01 to 2013-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2014-01-01 to 2014-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2015-01-01 to 2015-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2016-01-01 to 2016-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2017-01-01 to 2017-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2018-01-01 to 2018-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2019-01-01 to 2019-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2020-01-01 to 2020-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2021-01-01 to 2021-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2022-01-01 to 2022-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2023-01-01 to 2023-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# sliced 2024-01-01 to 2024-12-17
#    fixed coordinate and variable names
#    added cyclic coordinate
# computed list
# concatenated data
# wrote data to disk
# CPU times: user 2min 33s, sys: 7.4 s, total: 2min 41s
# Wall time: 2min 38s

# %%
client.shutdown()
